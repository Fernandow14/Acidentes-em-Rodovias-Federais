# %%
#importando a biblioteca pandas e lendo o arquivo de 2023,2024 e 2025
import pandas as pd



df_2023 = pd.read_csv(
    "../data/raw/acidentes2023_todas_causas.csv",
    sep=";",
    encoding="latin1"
)


df_2024 = pd.read_csv(
    "../data/raw/acidentes2024_todas_causas.csv",
    sep=";",
    encoding="latin1"
)

df_2025 = pd.read_csv(
    "../data/raw/acidentes2025_todas_causas.csv",
    sep=";",
    encoding="latin1"
)

# %%
#exibindo o formato dos dataframes e visualizando o tamanho das tabelas
df_2023.shape, df_2024.shape, df_2025.shape
# Out:
# ((571052, 37), (603215, 37), (528380, 37))

# %%
#visualizando as colunas do dataframes 2023
df_2023.columns
# Out:
# Index(['id', 'pesid', 'data_inversa', 'dia_semana', 'horario', 'uf', 'br',
#        'km', 'municipio', 'causa_principal', 'causa_acidente',
#        'ordem_tipo_acidente', 'tipo_acidente', 'classificacao_acidente',
#        'fase_dia', 'sentido_via', 'condicao_metereologica', 'tipo_pista',
#        'tracado_via', 'uso_solo', 'id_veiculo', 'tipo_veiculo', 'marca',
#        'ano_fabricacao_veiculo', 'tipo_envolvido', 'estado_fisico', 'idade',
#        'sexo', 'ilesos', 'feridos_leves', 'feridos_graves', 'mortos',
#        'latitude', 'longitude', 'regional', 'delegacia', 'uop'],
#       dtype='str')

# %%
df_2023.head(20)
# Out:
#         id      pesid data_inversa dia_semana   horario  uf     br     km  \
# 0   496506  1082142.0   2023-01-01    domingo  00:15:00  MG  116.0    587
# 1   496506  1082142.0   2023-01-01    domingo  00:15:00  MG  116.0    587
# 2   496506  1082142.0   2023-01-01    domingo  00:15:00  MG  116.0    587
# 3   496506  1082142.0   2023-01-01    domingo  00:15:00  MG  116.0    587
# 4   496507  1082138.0   2023-01-01    domingo  00:20:00  MG  381.0  686,5
# 5   496512  1082879.0   2023-01-01    domingo  00:55:00  RS  386.0  353,2
# 6   496512  1082877.0   2023-01-01    domingo  00:55:00  RS  386.0  353,2
# 7   496512  1082884.0   2023-01-01    domingo  00:55:00  RS  386.0  353,2
# 8   496512  1082224.0   2023-01-01    domingo  00:55:00  RS  386.0  353,2
# 9   496512  1082880.0   2023-01-01    domingo  00:55:00  RS  386.0  353,2
# 10  496512  1082879.0   2023-01-01    domingo  00:55:00  RS  386.0  353,2
# 11  496512  1082877.0   2023-01-01    domingo  00:55:00  RS  386.0  353,2
# ...

# %%
#visualizando as colunas do dataframes 2024
df_2024.columns
# Out:
# Index(['id', 'pesid', 'data_inversa', 'dia_semana', 'horario', 'uf', 'br',
#        'km', 'municipio', 'causa_principal', 'causa_acidente',
#        'ordem_tipo_acidente', 'tipo_acidente', 'classificacao_acidente',
#        'fase_dia', 'sentido_via', 'condicao_metereologica', 'tipo_pista',
#        'tracado_via', 'uso_solo', 'id_veiculo', 'tipo_veiculo', 'marca',
#        'ano_fabricacao_veiculo', 'tipo_envolvido', 'estado_fisico', 'idade',
#        'sexo', 'ilesos', 'feridos_leves', 'feridos_graves', 'mortos',
#        'latitude', 'longitude', 'regional', 'delegacia', 'uop'],
#       dtype='str')

# %%
df_2024.head(20)
# Out:
#           id      pesid data_inversa     dia_semana   horario  uf     br  \
# 0   571772.0  1268971.0   2024-01-01  segunda-feira  00:05:00  RJ  101.0
# 1   571774.0  1268985.0   2024-01-01  segunda-feira  00:05:00  GO  153.0
# 2   571774.0  1268985.0   2024-01-01  segunda-feira  00:05:00  GO  153.0
# 3   571777.0  1269020.0   2024-01-01  segunda-feira  01:45:00  ES  101.0
# 4   571778.0  1269028.0   2024-01-01  segunda-feira  00:45:00  SC  101.0
# 5   571778.0  1269045.0   2024-01-01  segunda-feira  00:45:00  SC  101.0
# 6   571778.0  1269028.0   2024-01-01  segunda-feira  00:45:00  SC  101.0
# 7   571778.0  1269045.0   2024-01-01  segunda-feira  00:45:00  SC  101.0
# 8   571779.0  1268998.0   2024-01-01  segunda-feira  01:45:00  RS  116.0
# 9   571779.0  1268999.0   2024-01-01  segunda-feira  01:45:00  RS  116.0
# 10  571779.0  1269000.0   2024-01-01  segunda-feira  01:45:00  RS  116.0
# 11  571779.0  1268976.0   2024-01-01  segunda-feira  01:45:00  RS  116.0
# ...

# %%
#visualizando as colunas do dataframes 2025
df_2025.columns
# Out:
# Index(['id', 'pesid', 'data_inversa', 'dia_semana', 'horario', 'uf', 'br',
#        'km', 'municipio', 'causa_principal', 'causa_acidente',
#        'ordem_tipo_acidente', 'tipo_acidente', 'classificacao_acidente',
#        'fase_dia', 'sentido_via', 'condicao_metereologica', 'tipo_pista',
#        'tracado_via', 'uso_solo', 'id_veiculo', 'tipo_veiculo', 'marca',
#        'ano_fabricacao_veiculo', 'tipo_envolvido', 'estado_fisico', 'idade',
#        'sexo', 'ilesos', 'feridos_leves', 'feridos_graves', 'mortos',
#        'latitude', 'longitude', 'regional', 'delegacia', 'uop'],
#       dtype='str')

# %%
df_2025.head(20)
# Out:
#         id      pesid data_inversa    dia_semana   horario  uf     br     km  \
# 0   652468  1467636.0   2025-01-01  quarta-feira  00:30:00  PE  101.0   89,5
# 1   652468  1467635.0   2025-01-01  quarta-feira  00:30:00  PE  101.0   89,5
# 2   652468  1467634.0   2025-01-01  quarta-feira  00:30:00  PE  101.0   89,5
# 3   652468  1467637.0   2025-01-01  quarta-feira  00:30:00  PE  101.0   89,5
# 4   652469  1467628.0   2025-01-01  quarta-feira  00:50:00  SC  101.0    120
# 5   652469  1467627.0   2025-01-01  quarta-feira  00:50:00  SC  101.0    120
# 6   652470  1467671.0   2025-01-01  quarta-feira  01:15:00  GO  153.0    414
# 7   652470  1467672.0   2025-01-01  quarta-feira  01:15:00  GO  153.0    414
# 8   652470  1467670.0   2025-01-01  quarta-feira  01:15:00  GO  153.0    414
# 9   652470  1467669.0   2025-01-01  quarta-feira  01:15:00  GO  153.0    414
# 10  652470  1467668.0   2025-01-01  quarta-feira  01:15:00  GO  153.0    414
# ...

# %%
#visualizando os tipos de dados das colunas do dataframe 2023
df_2023.dtypes
# Out:
# id                          int64
# pesid                     float64
# data_inversa                  str
# dia_semana                    str
# horario                       str
# uf                            str
# br                        float64
# km                            str
# municipio                     str
# causa_principal               str
# causa_acidente                str
# ordem_tipo_acidente         int64
# tipo_acidente                 str
# classificacao_acidente        str
# fase_dia                      str
# sentido_via                   str
# condicao_metereologica        str
# tipo_pista                    str
# tracado_via                   str
# uso_solo                      str
# id_veiculo                float64
# tipo_veiculo                  str
# marca                         str
# ano_fabricacao_veiculo    float64
# tipo_envolvido                str
# estado_fisico                 str
# idade                     float64
# ...

# %%
#latitude não apareceu nos tipos de dados - verificando se existe
"latitude" in df_2023.columns
# Out:
# True

# %%
df_2023["latitude"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
#visualizando os tipos de dados das colunas do dataframe 2024
df_2024.dtypes
# Out:
# id                        float64
# pesid                     float64
# data_inversa                  str
# dia_semana                    str
# horario                       str
# uf                            str
# br                        float64
# km                            str
# municipio                     str
# causa_principal               str
# causa_acidente                str
# ordem_tipo_acidente         int64
# tipo_acidente                 str
# classificacao_acidente        str
# fase_dia                      str
# sentido_via                   str
# condicao_metereologica        str
# tipo_pista                    str
# tracado_via                   str
# uso_solo                      str
# id_veiculo                float64
# tipo_veiculo                  str
# marca                         str
# ano_fabricacao_veiculo    float64
# tipo_envolvido                str
# estado_fisico                 str
# idade                     float64
# ...

# %%
#Usando uma condição para verificar se a coluna latitude existe no dataframe 2024.

if "latitude" in df_2024.columns:
    print("A coluna 'latitude' existe.")
    print("Tipo de dado:", df_2024["latitude"].dtype)
else:
    print("A coluna 'latitude' NÃO existe.")
# Out:
# A coluna 'latitude' existe.
# Tipo de dado: float64

# %%
#visualizando os tipos de dados das colunas do dataframe 2025
df_2025.dtypes
# Out:
# id                          int64
# pesid                     float64
# data_inversa                  str
# dia_semana                    str
# horario                       str
# uf                            str
# br                        float64
# km                            str
# municipio                     str
# causa_principal               str
# causa_acidente                str
# ordem_tipo_acidente         int64
# tipo_acidente                 str
# classificacao_acidente        str
# fase_dia                      str
# sentido_via                   str
# condicao_metereologica        str
# tipo_pista                    str
# tracado_via                   str
# uso_solo                      str
# id_veiculo                float64
# tipo_veiculo                  str
# marca                         str
# ano_fabricacao_veiculo    float64
# tipo_envolvido                str
# estado_fisico                 str
# idade                     float64
# ...

# %%
#Passando uma condição para verificar se a coluna latitude existe no dataframe 2025.

if "latitude" in df_2025.columns:
    print("A coluna 'latitude' existe.")
    print("Tipo de dado:", df_2025["latitude"].dtype)
else:
    print("A coluna 'latitude' NÃO existe.")
# Out:
# A coluna 'latitude' existe.
# Tipo de dado: str

# %% [markdown]
# #ANALISANDO O TIPO DE DADOS, JÁ CONSEGUIR EXERGA TIPOS QUE PRECISAM SER CONVERTIDOS PARA OUTROS TIPOS MAIS ADEQUADOS.
#
# data_inversa str para data /
# horario str para hora /
# longitude str para float (verificar porque está como str, pode ter valores nulos) /
# latitude 2023 é str mudar para float (verificar porque está como str, pode ter valores nulos) /
# latitude 2024 é float ( está ok) /
# latitude 2025 é str mudar para float e corrigir nulos /
# pesid float para int /
# id_veiculo float para int /
# km float para int /
# ano_fabricação float para int

# %%
#meu arquivo é muito grande difícil para visualizar os dados, então vou visualizar apenas as colunas com nulos

df_2023.isnull().sum()[df_2023.isnull().sum() > 0]
# Out:
# pesid                      55887
# br                          1836
# km                          1836
# classificacao_acidente         3
# id_veiculo                 20772
# tipo_veiculo               20772
# ano_fabricacao_veiculo     20772
# tipo_envolvido             55887
# estado_fisico              55887
# idade                     105448
# sexo                       55887
# ilesos                     55887
# feridos_leves              55887
# feridos_graves             55887
# mortos                     55887
# regional                     150
# delegacia                    557
# uop                          656
# dtype: int64

# %%
df_2024.isnull().sum()[df_2024.isnull().sum() > 0]
# Out:
# pesid                      57641
# br                          1348
# km                          1348
# classificacao_acidente         3
# id_veiculo                 19572
# tipo_veiculo               19572
# ano_fabricacao_veiculo     19572
# tipo_envolvido             57641
# estado_fisico              57641
# idade                     109408
# sexo                       57641
# ilesos                     57641
# feridos_leves              57641
# feridos_graves             57641
# mortos                     57641
# regional                      27
# delegacia                    183
# uop                         1663
# dtype: int64

# %%
df_2025.isnull().sum()[df_2025.isnull().sum() > 0]
# Out:
# pesid                     52465
# br                         1263
# km                         1263
# classificacao_acidente        7
# id_veiculo                16918
# tipo_veiculo              16918
# ano_fabricacao_veiculo    16918
# tipo_envolvido            52465
# estado_fisico             52465
# idade                     96411
# sexo                      52465
# ilesos                    52465
# feridos_leves             52465
# feridos_graves            52465
# mortos                    52465
# regional                     16
# delegacia                   190
# uop                         436
# dtype: int64

# %%
#verificando se os três anos tem as mesmas colunas com nulos

nulos_2023 = set(df_2023.columns[df_2023.isnull().any()])
nulos_2024 = set(df_2024.columns[df_2024.isnull().any()])
nulos_2025 = set(df_2025.columns[df_2025.isnull().any()])

# %%
#verificando se os três anos tem as mesmas colunas com nulos

mesmas_colunas_nulas = (nulos_2023 == nulos_2024 == nulos_2025)

mesmas_colunas_nulas
# Out:
# True
